# %% [markdown]
# # Project 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
# displaying top 2 records for the file
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
# displaying top 2 records for the file
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
# to display the metadata information about the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
# to display the metadata information about the data frame
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# # Q2

# %%
row=df.index.values
row
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
row1=df1.index.values
row1
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# # Q3

# %%
# Column Name modified from Indicator to Indicator_id 
df.rename(columns={'Indicator':'Indicator_id'}).head()
# Out:
#                         Indicator_id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.rename(columns={'Indicator':'Indicator_id'}, inplace=True)
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Column Name modified from PUBLISH STATES to Publication StatusIndicator_id  and WHO region to WHO Regionpermanantly
df.rename(columns={'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'}, inplace=True)
df.head(2)
# Out:
#                        Indicator_id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# sorting the dataframe df by ascending order based on column Year
#(default value for ascending is true so by default the soring will be ascending order)
df.sort_values(by = ['Year']).head(10)
# Out:
#                            Indicator_id Publication Status  Year  \
# 0      Life expectancy at birth (years)          Published  1990
# 1270   Life expectancy at birth (years)          Published  1990
# 3193   Life expectancy at birth (years)          Published  1990
# 3194   Life expectancy at birth (years)          Published  1990
# 3197  Life expectancy at age 60 (years)          Published  1990
# 1264   Life expectancy at birth (years)          Published  1990
# 3199  Life expectancy at age 60 (years)          Published  1990
# 1262  Life expectancy at age 60 (years)          Published  1990
# 1259   Life expectancy at birth (years)          Published  1990
# 3203  Life expectancy at age 60 (years)          Published  1990
#
#            WHO Region World Bank income group              Country  \
# 0              Europe             High-income              Andorra
# 1270           Europe             High-income              Germany
# ...

# %%
#get a list of columns
cols = list(df)
cols
# Out:
# ['Indicator_id',
#  'Publication Status',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Country',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
# move the column to head of list using index, pop and insert
cols.insert(0, cols.pop(cols.index('Country')))
# using loc to reorder the columns
df_update = df.loc[:, cols]
df_update.head(4)
# Out:
#    Country                       Indicator_id Publication Status  Year  \
# 0  Andorra   Life expectancy at birth (years)          Published  1990
# 1  Andorra   Life expectancy at birth (years)          Published  2000
# 2  Andorra  Life expectancy at age 60 (years)          Published  2012
# 3  Andorra  Life expectancy at age 60 (years)          Published  2000
#
#   WHO Region World Bank income group         Sex  Display Value  Numeric  Low  \
# 0     Europe             High-income  Both sexes             77     77.0  NaN
# 1     Europe             High-income  Both sexes             80     80.0  NaN
# 2     Europe             High-income      Female             28     28.0  NaN
# 3     Europe             High-income  Both sexes             23     23.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN
# 3   NaN       NaN

# %%
# Selecting the WHO region column values into one array variable
col2=df['WHO Region'].values
#Displaying vallues of the array variable 
col2
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
# Selecting the specified rows with all the column values into one data set
subset = df.iloc[[11,24,37],:]
subset
# Out:
#                          Indicator_id Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %%
subset2 = df.iloc[[11,24,37],[0,3,7]]
subset
# Out:
#                          Indicator_id       WHO Region  Display Value
# 11   Life expectancy at birth (years)           Europe             83
# 24  Life expectancy at age 60 (years)  Western Pacific             21
# 37  Life expectancy at age 60 (years)           Europe             26

# %%
# Dropping the rows 5,12,23 and 56 using drop by row index vlues
df.drop([5,12,23,56]).head(10) # row index 5 is missed in below output of first 10 rows
# Out:
#                          Indicator_id Publication Status  Year  \
# 0    Life expectancy at birth (years)          Published  1990
# 1    Life expectancy at birth (years)          Published  2000
# 2   Life expectancy at age 60 (years)          Published  2012
# 3   Life expectancy at age 60 (years)          Published  2000
# 4    Life expectancy at birth (years)          Published  2012
# 6   Life expectancy at age 60 (years)          Published  1990
# 7   Life expectancy at age 60 (years)          Published  2012
# 8    Life expectancy at birth (years)          Published  2012
# 9    Life expectancy at birth (years)          Published  2000
# 10   Life expectancy at birth (years)          Published  2012
#
#                WHO Region World Bank income group               Country  \
# 0                  Europe             High-income               Andorra
# 1                  Europe             High-income               Andorra
# ...

# %%
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.columns
# Out:
# Index(['UserID', 'User', 'Gender', 'Registered', 'Cancelled'], dtype='object')

# %%
users.head(2)
# Out:
#    UserID     User Gender  Registered   Cancelled
# 0       1  Charles   male  2012-12-21         NaN
# 1       2    Pedro   male  2010-08-01  2010-08-08

# %%
sessions.head(2)
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2

# %%
products.head(2)
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04

# %% [markdown]
# # Q10

# %%
transactions.head(2)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1

# %% [markdown]
# # Q11

# %%
#Merging the data frame using Left join based on user ID and assigning to result dataframe
Data_M = pd.merge(transactions, users, on='UserID', how='left', sort=False);
#Displaying the result data fram
Data_M
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %% [markdown]
# # Q12

# %%
# Merging two data frames with left join as transactions table as left with indicator as True  
colm = pd.merge(transactions, users, on='UserID', how='left', sort=False,indicator=True);
colm
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled     _merge
# 0     NaN         NaN         NaN  left_only
# 1  female  2012-10-23  2016-06-07       both
# ...

# %% [markdown]
# # Q13

# %%
# filtering only left only rows which results rows which are in only transaction dataframe (like Outer - Inner join)
result1 = Merged[Merged['_merge']=='left_only']
#Displaying only Transaction data frame columns 
result1.iloc[:,0:5]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %% [markdown]
# # Q14

# %%
# Joining the two data frames with inner join on UserID column and assigning to the result2 
Inn_R = pd.merge(transactions, users, on='UserID', how='inner', sort=False);
#Displaying the result data fram
Inn_R
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# # Q15

# %%
# Joining the two data frames with Outer join on UserID column and assigning to the Out_m 
Out_M = pd.merge(transactions, users, on='UserID', how='outer', sort=False);
#Displaying the result data fram
Out_M
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# # Q16

# %%
# Merging two data frames in to result4 where the User id registered date and session date are same
result4 = pd.merge(users,sessions,left_on=[users.UserID,users.Registered],
                 right_on=[sessions.UserID,sessions.SessionDate],copy=False,sort=False)
#Displaying the result data frame
result4.iloc[:,2:-1]
# Out:
#    UserID_x     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0         2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1         4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %% [markdown]
# # Q17

# %%
# Creating Tempaorary column  with value 1 in both the data frames for join
users['temp']=1
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled  temp
# 0       1   Charles    male  2012-12-21         NaN     1
# 1       2     Pedro    male  2010-08-01  2010-08-08     1
# 2       3  Caroline  female  2012-10-23  2016-06-07     1
# 3       4   Brielle  female  2013-07-17         NaN     1
# 4       5  Benjamin    male  2010-11-25         NaN     1

# %%
products['temp']=1
products.head()
# Out:
#    ProductID Product  Price  temp
# 0          1       A  14.16     1
# 1          2       B  33.04     1
# 2          3       C  10.65     1
# 3          4       D  10.02     1
# 4          5       E  29.66     1

# %%
# Merging dataframes into results based on Temp column with Outer Join 
result5 = pd.merge(users,products,on='temp',how='outer')
result5
# Out:
#     UserID      User  Gender  Registered   Cancelled  temp  ProductID Product  \
# 0        1   Charles    male  2012-12-21         NaN     1          1       A
# 1        1   Charles    male  2012-12-21         NaN     1          2       B
# 2        1   Charles    male  2012-12-21         NaN     1          3       C
# 3        1   Charles    male  2012-12-21         NaN     1          4       D
# 4        1   Charles    male  2012-12-21         NaN     1          5       E
# 5        2     Pedro    male  2010-08-01  2010-08-08     1          1       A
# 6        2     Pedro    male  2010-08-01  2010-08-08     1          2       B
# 7        2     Pedro    male  2010-08-01  2010-08-08     1          3       C
# 8        2     Pedro    male  2010-08-01  2010-08-08     1          4       D
# 9        2     Pedro    male  2010-08-01  2010-08-08     1          5       E
# 10       3  Caroline  female  2012-10-23  2016-06-07     1          1       A
# ...

# %%
#Displaying the required columns UserID and ProductID from result data frame
result5.loc[:,["UserID","ProductID"]]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5
